# %% [markdown]
# ## Division("\\"): It returns the arithmatic quotient
# ## FloorDivision("\\\\"): It returns the arithmatic quotient WITHOUT decimal digits
# ## Modulo("%"): it returns the remainder (X-Y*(X\\\Y))
# ## Exponent(**): Calculates power of the number

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
8/5
# Out:
# 1.6

# %%
8//5
# Out:
# 1

# %%
8%5
# Out:
# 3

# %%
5**8
# Out:
# 390625

# %%
-+5
# Out:
# -5

# %%
+-5
# Out:
# -5

# %%
3--5
# Out:
# 8

# %%
5---7
# Out:
# -2

# %%
w=eval(input('Enter the weight in grams: '))
k=w//1000
g=w%1000
print('Weight is of',k,'KG',g, 'Grams')
# Out:
# Enter the weight in grams: 968745
# Weight is of 968 KG 745 Grams

# %%
p = eval(input('Enter the principle amount: '))
t = eval(input('Enter the time period: '))
r = eval(input('Enter the rate of interest amount: '))

res = (p*t*r)/100

print("Simple interest: ", format(res, '.2f'))
# Out:
# Enter the principle amount: 2541
# Enter the time period: 2.5
# Enter the rate of interest amount: 5.3
# Simple interest:  336.68

# %%
x1=eval(input('Enter the X1 coordinate: '))
x2=eval(input('Enter the X2 coordinate: '))
y1=eval(input('Enter the y1 coordinate: '))
y2=eval(input('Enter the y2 coordinate: '))
d=((x1-x2)**2+(y1-y2)**2)**0.5
print('Distance between the points is: ',format(d,'0.3f'))
# Out:
# Enter the X1 coordinate: 1
# Enter the X2 coordinate: 2
# Enter the y1 coordinate: 3
# Enter the y2 coordinate: 4
# Distance between the points is:  1.414

# %%
p=eval(input('Enter P value: '))
q=eval(input('Enter Q value: '))
z=((2+8*p)/2)-((p-q)*(p+q)/2)+(((p+q)/2)*4)
print(z)
# Out:
# Enter P value: 4
# Enter Q value: 2
# 23.0

# %%
r=eval(input('Enter the radius of the circle: '))
area = 3.142*r**2
print(format(area,'0.2f'))
# Out:
# Enter the radius of the circle: 2
# 12.57

# %%
print(15+20/5+3*2-1)
# Out:
# 24.0

# %%
print(format(20/6, '0.2f'))
# Out:
# 3.33

# %%
print(format(20//6, '0.2f'))
# Out:
# 3.00

# %%
print(format(20%6, '0.2f'))
# Out:
# 2.00

# %%
print(7//4/2)
# Out:
# 0.5

# %%
4*1**2
# Out:
# 4

# %%
4.6//1
# Out:
# 4.0

# %%
5<<5
# Out:
# 160

# %%
p=eval(input('Enter P value: '))
q=eval(input('Enter q value: '))
a=(p+q-abs(p-q))//2
print(a)
# Out:
# Enter P value: 5
# Enter q value: 4
# 4

# %%
area=0
lenght=0
breadth=0

l=eval(input('Enter P value: '))
b=eval(input('Enter P value: '))
area=l*b
print("Area of the Rectangle: ", area)
# Out:
# Enter P value: 2
# Enter P value: 8
# Area of the Rectangle:  16

# %%
num3=int(input('Enter the 5 digit number: '))
r1=num3%100
q1=num3//10
r2=q1%10
q2=q1//10
r3=q2%10
q3=q2//10
r4=q3%10
q4=q3//10
r5=q4%10
print('Sum of the digits is', r1+r2+r3+r4+r5)
# Out:
# Enter the 5 digit number: 12451
# Sum of the digits is 63
