# %% [markdown]
# ## TOKEN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Literal: These are numerical or strings or characters

# %% [markdown]
# ##### Examples: 78, 21.34, 'hi', Q

# %% [markdown]
# ### Keywords: these are reserved words with fixed meaning assigned to them, keywords cannot be identifiers or variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Operator: Operates the statements, Arithmatic, relational, logical and bitwise

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Delimiter: performs grouping, punctualing and assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Integer: combination of positive and negative and including zero.

# %% [markdown]
# ### 2.4 Python DATA TYPES

# %%
10 # DECI
# Out:
# 10

# %%
0o12 # OCTAL
# Out:
# 10

# %%
0o100
# Out:
# 64

# %%
0x20 # HEXA
# Out:
# 32

# %% [markdown]
# ### converting STRING to INT

# %%
a = '123'  #TRY: a = 'hello', will get base 10 error
type(a)
# Out:
# str

# %%
b = int(a)
type(b)
# Out:
# int

# %% [markdown]
# ### Float: It consists of a whole number, decimal point and fractional number

# %%
3.7e1
# Out:
# 37.0

# %%
3.7e2
# Out:
# 370.0

# %% [markdown]
# ### converting STRING to FLOAT

# %%
c = '20.5'
type(c)
# Out:
# str

# %%
d = float(c)
type(d)
# Out:
# float

# %% [markdown]
# #### Complex number : a+bj

# %%
k = 2+4j
type(k)
# Out:
# complex

# %% [markdown]
# ### Boolean: True and Flase

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
3 ==5
# Out:
# False

# %%
5<4
# Out:
# False

# %%
6>4
# Out:
# True

# %% [markdown]
# ### STRING type: combination of words or sentences

# %%
D = 'Python is a high level language'
D
# Out:
# 'Python is a high level language'

# %% [markdown]
# ### converting FLOAT to STRING

# %%
m = 12.5
type(m)
# Out:
# float

# %%
n = str(m)
type(n)
# Out:
# str

# %% [markdown]
# ### string CONCATENATION (+) operator: combines two diff strings

# %%
"wooow " + 'Python programminggggg'
# Out:
# 'wooow Python programminggggg'

# %% [markdown]
# ### 2.5 print() Function: Display the contents on the screen

# %%
print()

# %% [markdown]
# ### print statements with double quotes, use Blackslash(\\)

# %%
print("Smells great! \"may I know your perfume\"")
# Out:
# Smells great! "may I know your perfume"

# %%
print('hi')
print('hello')
print('nice')
# Out:
# hi
# hello
# nice

# %%
print('hi', end=' ')
print('hello', end=', ')
print('nice', end=' ')
# Out:
# hi hello, nice

# %% [markdown]
# ## 2.6 BASSIGN VALUE TO VARIABLE

# %%
Z = 4
Z
# Out:
# 4

# %%
radius = 6
radius
# Out:
# 6

# %%
r = radius + Z
r
# Out:
# 10

# %%
p = q = r = 1000

# %%
p
# Out:
# 1000

# %%
r
# Out:
# 1000

# %% [markdown]
# ### Note: A variable MUST be asssigned a value before it can be used in an expression

# %%
count = 1 
z = count + 5
z
# Out:
# 6

# %% [markdown]
# ## 2.7 MULTIPLE ASSIGNMENTS
#
# ### Var1, Var 2, Var3 .........VarN = Exp1, Exp2, Exp3.........ExpN

# %% [markdown]
# ### Swapping using multiple assignment

# %%
p = 10
q = 20

print('p = ',p)
print('q = ',q)

p, q = q, p

print('\nSwapped results')
print('p = ',p)
print('q = ',q)
# Out:
# p =  10
# q =  20
#
# Swapped results
# p =  20
# q =  10

# %% [markdown]
# ## 2.9 THE input() FUNCTION
#
# ### variable_name = input("string")
# ### a = input('Enter number')

# %%
a = input('Enter the number')
print('type of "a" is ', type(a))
# Out:
# Enter the number10
# type of "a" is  <class 'str'>

# %% [markdown]
# ### Note: Input function produces only STRINGS

# %%
b = input('Enter the number')

print('type of "a" is ', type(b))

b = int(b)
print('type of "a" is ', type(b), "converted to INT")
# Out:
# Enter the number9
# type of "a" is  <class 'str'>
# type of "a" is  <class 'int'> converted to INT

# %%
num1 = int(input('Enter integer value: '))
num2 = float(input('Enter float value: '))

sum = num1 + num2
print(sum)
print(type(sum))
# Out:
# Enter integer value: 5
# Enter float value: 2.4
# 7.4
# <class 'float'>

# %% [markdown]
# ## THE eval() FUNCTION

# %%
X = eval('123')
print(type(X))

m = eval('2.5')
print(type(m))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### eval() to input() function
#
# ### Note: programmer doesn't know what value he can enter, they may enter int, float, string, complex by using eval() python auto determines the type

# %%
age = eval(input('Enter the age'))
height = eval(input('Enter the height'))
name = (input('Enter the name'))

print(type(age))
print(type(height))
print(type(name))
# Out:
# Enter the age9
# Enter the height3.5
# Enter the namekjk
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## 2.11 FORMATTING NUMBER AND STRINGS
# ### format(item, format-specifier)

# %%
x = 1.6543
print(x)
format(x, ".2f")
# Out:
# 1.6543
# '1.65'

# %%
pi = 3.142
radius = eval(input('Enter the radius: '))
area = 2 * pi * radius

print('Area of the circle: ', area)
print('Area of the circle with format: ', format(area, ".2f"))
# Out:
# Enter the radius: 5
# Area of the circle:  31.419999999999998
# Area of the circle with format:  31.42

# %% [markdown]
# ## 2.12 Python INBUILT functions

# %%
abs(-2)  # absolute
# Out:
# 2

# %%
abs(4)
# Out:
# 4

# %%
print(max(2, 22, 61, 3, 4))
print(min(2, 22, 61, 3, 4))
print(pow(2, 3))
print(round(3.123))
print(round(3.5123))
# Out:
# 61
# 2
# 8
# 3
# 4

# %% [markdown]
# ## Exercise

# %%
round(1.5)-round(-1.5)
# Out:
# 4

# %%
# print({:,}.format(100000))

# %%
n1 = input('Enter n1:')
n2 = input('Enter n2:')

res1 = n1+n2
print(res1)
print(type(res1))

n3 = eval(n1)
n4 = eval(n2)

res2 = n3+n4
print(res2)
print(type(res2))
# Out:
# Enter n1:1
# Enter n2:2
# 12
# <class 'str'>
# 3
# <class 'int'>
